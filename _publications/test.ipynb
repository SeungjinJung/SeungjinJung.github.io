# %% [markdown]
# title: "Active Instance Selection for Few-Shot Classification"
# collection: publications
# category: journals
# venue: IEEE Access
# excerpt: " <br> Junsup Shin, Yongwook Kang, **Seungjin Jung** and Jongwon Choi\\* <br>\\[Impact Factor = 3.9\\] \\[paper\\]"
